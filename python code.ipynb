# %%
import numpy as np
import pandas as pd
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from matplotlib.dates import DateFormatter

# %%
df = pd.read_csv("Work Term Report Data.csv")
df.head()
# Out:
#        Date  Barcelona_Fabra Daily Rainfall [mm]  \
# 0  1/1/2003                                  0.0
# 1  1/2/2003                                  0.0
# 2  1/3/2003                                  0.0
# 3  1/4/2003                                  0.0
# 4  1/5/2003                                 18.1
#
#    Barcelona Daily Rainfall [mm]  Sabadell_Aero Daily Rainfall [mm]  \
# 0                            0.0                                0.0
# 1                            0.0                                NaN
# 2                            0.0                                NaN
# 3                            0.0                                0.0
# 4                           16.4                                2.1
#
#    Garriga Discharge [m^3]  Castellar Discharge [m^3]  Llica Discharge [m^3]  \
# 0                    0.254                     0.0327                  0.155
# 1                    0.254                     0.0281                  0.151
# 2                    0.246                     0.0225                  0.145
# 3                    0.251                     0.0300                  0.145
# 4                    0.241                     0.0328                  0.146
#
#    Montornes Discharge [m^3]  Mogoda Discharge [m^3]  Gramenet Discharge [m^3]
# 0                     0.3985                   0.120                    3.6275
# 1                     0.3745                   0.106                    3.9471
# 2                     0.3750                   0.101                    4.0174
# 3                     0.3720                   0.099                    3.9316
# 4                     0.3686                   0.097                    3.7913

# %%
plt.figure(figsize=(20, 60))

# %%
dates = pd.to_datetime(df.iloc[:,0])  # Convert the first column to datetime
num_cols = len(df.columns) - 1  # Number of columns to plot, excluding the first column

# Create subplots for each column
fig, axs = plt.subplots(num_cols, 1, figsize=(10, 5*num_cols))

# Plot each column as a separate plot
for i, col in enumerate(df.columns[1:]):
    axs[i].plot(dates, df[col])
    axs[i].set_title(col)
    axs[i].set_ylabel('Value')
    axs[i].set_xlabel('Date')

# Set the x-axis label for the last plot


# Adjust subplot spacing
fig.tight_layout()

# Show the plot
plt.show()

# %%
dates = pd.to_datetime(df.iloc[:,0])  # Convert the first column to datetime
num_cols = len(df.columns) - 1  # Number of columns to plot, excluding the first column

# Create subplots for each column
fig, axs = plt.subplots(num_cols, 1, figsize=(10, 5*num_cols))

# Plot each column as a separate plot
for i, col in enumerate(df.columns[1:]):
    axs[i].plot(dates, df[col])
    axs[i].set_title(col)
    axs[i].set_ylabel('Value')
    axs[i].set_xlabel('Date')

    axs[i].plot(dates, df.iloc[:, -1])


# Adjust subplot spacing
fig.tight_layout()

# Show the plot
plt.show()

# %%
sns.heatmap(df.iloc[:,2:].isnull(), cbar=False)
plt.ylabel('Days')
plt.xlabel('Location and Type of Measurement')
plt.title('Heatmap of Missing Data')
plt.show()

# %%
df.drop('Castellar Discharge [m^3]', inplace = True, axis=1)
df.drop('Montornes Discharge [m^3]', inplace = True, axis=1)
df.head()
# Out:
#        Date  Barcelona_Fabra Daily Rainfall [mm]  \
# 0  1/1/2003                                  0.0
# 1  1/2/2003                                  0.0
# 2  1/3/2003                                  0.0
# 3  1/4/2003                                  0.0
# 4  1/5/2003                                 18.1
#
#    Barcelona Daily Rainfall [mm]  Sabadell_Aero Daily Rainfall [mm]  \
# 0                            0.0                                0.0
# 1                            0.0                                NaN
# 2                            0.0                                NaN
# 3                            0.0                                0.0
# 4                           16.4                                2.1
#
#    Garriga Discharge [m^3]  Llica Discharge [m^3]  Mogoda Discharge [m^3]  \
# 0                    0.254                  0.155                   0.120
# 1                    0.254                  0.151                   0.106
# 2                    0.246                  0.145                   0.101
# 3                    0.251                  0.145                   0.099
# 4                    0.241                  0.146                   0.097
#
#    Gramenet Discharge [m^3]
# 0                    3.6275
# 1                    3.9471
# 2                    4.0174
# 3                    3.9316
# 4                    3.7913

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 2922 non-null   object
#  1   Barcelona_Fabra Daily Rainfall [mm]  2679 non-null   float64
#  2   Barcelona Daily Rainfall [mm]        2699 non-null   float64
#  3   Sabadell_Aero Daily Rainfall [mm]    2516 non-null   float64
#  4   Garriga Discharge [m^3]              2922 non-null   float64
#  5   Llica Discharge [m^3]                2922 non-null   float64
#  6   Mogoda Discharge [m^3]               2852 non-null   float64
#  7   Gramenet Discharge [m^3]             2922 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 182.8+ KB

# %%
df.corr()
# Out:
# C:\Users\hocke\AppData\Local\Temp\ipykernel_19796\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                      Barcelona_Fabra Daily Rainfall [mm]  \
# Barcelona_Fabra Daily Rainfall [mm]                             1.000000
# Barcelona Daily Rainfall [mm]                                   0.680609
# Sabadell_Aero Daily Rainfall [mm]                               0.806012
# Garriga Discharge [m^3]                                         0.170962
# Llica Discharge [m^3]                                           0.202106
# Mogoda Discharge [m^3]                                          0.369651
# Gramenet Discharge [m^3]                                        0.330710
#
#                                      Barcelona Daily Rainfall [mm]  \
# Barcelona_Fabra Daily Rainfall [mm]                       0.680609
# Barcelona Daily Rainfall [mm]                             1.000000
# Sabadell_Aero Daily Rainfall [mm]                         0.646151
# Garriga Discharge [m^3]                                   0.090237
# Llica Discharge [m^3]                                     0.126251
# Mogoda Discharge [m^3]                                    0.233462
# Gramenet Discharge [m^3]                                  0.201358
#
#                                      Sabadell_Aero Daily Rainfall [mm]  \
# Barcelona_Fabra Daily Rainfall [mm]                           0.806012
# Barcelona Daily Rainfall [mm]                                 0.646151
# Sabadell_Aero Daily Rainfall [mm]                             1.000000
# Garriga Discharge [m^3]                                       0.217428
# Llica Discharge [m^3]                                         0.178946
# Mogoda Discharge [m^3]                                        0.400147
# Gramenet Discharge [m^3]                                      0.338390
#
#                                      Garriga Discharge [m^3]  \
# Barcelona_Fabra Daily Rainfall [mm]                 0.170962
# Barcelona Daily Rainfall [mm]                       0.090237
# Sabadell_Aero Daily Rainfall [mm]                   0.217428
# Garriga Discharge [m^3]                             1.000000
# Llica Discharge [m^3]                               0.611243
# Mogoda Discharge [m^3]                              0.625492
# Gramenet Discharge [m^3]                            0.757268
#
#                                      Llica Discharge [m^3]  \
# Barcelona_Fabra Daily Rainfall [mm]               0.202106
# Barcelona Daily Rainfall [mm]                     0.126251
# Sabadell_Aero Daily Rainfall [mm]                 0.178946
# Garriga Discharge [m^3]                           0.611243
# Llica Discharge [m^3]                             1.000000
# Mogoda Discharge [m^3]                            0.612124
# Gramenet Discharge [m^3]                          0.655422
#
#                                      Mogoda Discharge [m^3]  \
# Barcelona_Fabra Daily Rainfall [mm]                0.369651
# Barcelona Daily Rainfall [mm]                      0.233462
# Sabadell_Aero Daily Rainfall [mm]                  0.400147
# Garriga Discharge [m^3]                            0.625492
# Llica Discharge [m^3]                              0.612124
# Mogoda Discharge [m^3]                             1.000000
# Gramenet Discharge [m^3]                           0.802983
#
#                                      Gramenet Discharge [m^3]
# Barcelona_Fabra Daily Rainfall [mm]                  0.330710
# Barcelona Daily Rainfall [mm]                        0.201358
# Sabadell_Aero Daily Rainfall [mm]                    0.338390
# Garriga Discharge [m^3]                              0.757268
# Llica Discharge [m^3]                                0.655422
# Mogoda Discharge [m^3]                               0.802983
# Gramenet Discharge [m^3]                             1.000000

# %%
df2 = df.copy(deep=True)

# %%
df = df.dropna()

# %%
df.info()
#Now we have clean data that can be used for the MLR analysis.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2076 entries, 0 to 2918
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 2076 non-null   object
#  1   Barcelona_Fabra Daily Rainfall [mm]  2076 non-null   float64
#  2   Barcelona Daily Rainfall [mm]        2076 non-null   float64
#  3   Sabadell_Aero Daily Rainfall [mm]    2076 non-null   float64
#  4   Garriga Discharge [m^3]              2076 non-null   float64
#  5   Llica Discharge [m^3]                2076 non-null   float64
#  6   Mogoda Discharge [m^3]               2076 non-null   float64
#  7   Gramenet Discharge [m^3]             2076 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 146.0+ KB

# %%
x = df.drop(['Date', 'Gramenet Discharge [m^3]'], axis=1)
y = df['Gramenet Discharge [m^3]']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=101)

# %%
# Create a linear regression model and train it using the specified training data.
model = LinearRegression()
model.fit(x_train, y_train)

predictions = model.predict(x_test)

# %%
fig, ax = plt.subplots()

forecast_dates = pd.to_datetime(df['Date'][-len(predictions):])

# Plot the two columns against each other
ax.plot(forecast_dates, predictions)
ax.set_ylabel('Discharge [m^3]')
ax.set_xlabel('Date')
ax.plot(forecast_dates, y_test, color='red')

ax.legend(['Actual Discharge', 'Forecasted Discharge'])
plt.title('MLR Forecast Results')

date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
export = pd.DataFrame({'List1': y_test, 'List2': predictions})

# Save the dataframe to an Excel file
export.to_excel('my_lists.xlsx', index=False)
